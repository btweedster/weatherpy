# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = list(zip(lats,lngs))

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coord in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coord[0],coord[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Generate params for query
    params = {'q':city.replace(" ","+"),'appid':weather_api_key,'units':'imperial'}
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(url,params=params).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity =city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat:": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | esna
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 8 of Set 1 | bambari
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | laguna
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | great bend
# City not found. Skipping...
# Processing Record 14 of Set 1 | lazaro cardenas
# City not found. Skipping...
# Processing Record 15 of Set 1 | sembe
# Processing Record 16 of Set 1 | mantua
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | osoyoos
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | svetlaya
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 28 of Set 1 | pau
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | vanavara
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | shimoda
# Processing Record 33 of Set 1 | margate
# Processing Record 34 of Set 1 | melfi
# Processing Record 35 of Set 1 | xiongshi
# City not found. Skipping...
# Processing Record 36 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | clyde river
# City not found. Skipping...
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | bambous virieux
# City not found. Skipping...
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | myitkyina
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | jacksonville
# Processing Record 50 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | lakes entrance
# City not found. Skipping...
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | antigonish
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | norman wells
# City not found. Skipping...
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | cuamba
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | pemba
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | cape town
# City not found. Skipping...
# Processing Record 15 of Set 2 | buzmeyin
# Processing Record 16 of Set 2 | okhotsk
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | oga
# Processing Record 20 of Set 2 | coquimbo
# Processing Record 21 of Set 2 | inirida
# Processing Record 22 of Set 2 | fare
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | westport
# Processing Record 25 of Set 2 | cayenne
# Processing Record 26 of Set 2 | tyarlevo
# Processing Record 27 of Set 2 | kudahuvadhoo
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | camacupa
# Processing Record 30 of Set 2 | richards bay
# City not found. Skipping...
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | praia da vitoria
# City not found. Skipping...
# Processing Record 33 of Set 2 | noumea
# Processing Record 34 of Set 2 | napoleon
# Processing Record 35 of Set 2 | chase
# Processing Record 36 of Set 2 | faya
# Processing Record 37 of Set 2 | izhma
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | agadez
# Processing Record 42 of Set 2 | muisne
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | khilok
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | biryusinsk
# Processing Record 49 of Set 2 | severiano melo
# City not found. Skipping...
# Processing Record 50 of Set 2 | arraial do cabo
# City not found. Skipping...
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 3 | tombouctou
# Processing Record 3 of Set 3 | alyangula
# Processing Record 4 of Set 3 | santa maria
# City not found. Skipping...
# Processing Record 5 of Set 3 | saint george
# City not found. Skipping...
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | jasper
# Processing Record 8 of Set 3 | sterling
# Processing Record 9 of Set 3 | sarandi
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | muroto
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | umm kaddadah
# City not found. Skipping...
# Processing Record 16 of Set 3 | samarai
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | wanning
# Processing Record 19 of Set 3 | valparaiso
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | san jeronimo
# City not found. Skipping...
# Processing Record 22 of Set 3 | vila velha
# City not found. Skipping...
# Processing Record 23 of Set 3 | buchanan
# Processing Record 24 of Set 3 | port hardy
# City not found. Skipping...
# Processing Record 25 of Set 3 | tocopilla
# Processing Record 26 of Set 3 | ishigaki
# Processing Record 27 of Set 3 | ayorou
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | sur
# Processing Record 33 of Set 3 | ji-parana
# City not found. Skipping...
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | san cristobal
# City not found. Skipping...
# Processing Record 36 of Set 3 | honavar
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | sao filipe
# City not found. Skipping...
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | east london
# City not found. Skipping...
# Processing Record 49 of Set 3 | makakilo city
# City not found. Skipping...
# Processing Record 50 of Set 3 | sept-iles
# Processing Record 1 of Set 4 | ribeira grande
# City not found. Skipping...
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | burns lake
# City not found. Skipping...
# Processing Record 5 of Set 4 | saint-pierre
# Processing Record 6 of Set 4 | kununurra
# Processing Record 7 of Set 4 | grand gaube
# City not found. Skipping...
# Processing Record 8 of Set 4 | mamou
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | scarborough
# Processing Record 12 of Set 4 | ponta do sol
# City not found. Skipping...
# Processing Record 13 of Set 4 | manta
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | daru
# Processing Record 17 of Set 4 | pochutla
# Processing Record 18 of Set 4 | eyemouth
# Processing Record 19 of Set 4 | torrington
# Processing Record 20 of Set 4 | nome
# Processing Record 21 of Set 4 | billings
# Processing Record 22 of Set 4 | kalaleh
# Processing Record 23 of Set 4 | chama
# Processing Record 24 of Set 4 | aswan
# Processing Record 25 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 4 | bandarbeyla
# Processing Record 27 of Set 4 | ramsar
# Processing Record 28 of Set 4 | fort nelson
# City not found. Skipping...
# Processing Record 29 of Set 4 | kutum
# Processing Record 30 of Set 4 | tasiilaq
# Processing Record 31 of Set 4 | borogontsy
# Processing Record 32 of Set 4 | loa janan
# City not found. Skipping...
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | acarau
# Processing Record 35 of Set 4 | cherskiy
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | basco
# Processing Record 38 of Set 4 | along
# Processing Record 39 of Set 4 | waipawa
# Processing Record 40 of Set 4 | kiriakion
# City not found. Skipping...
# Processing Record 41 of Set 4 | santiago del estero
# City not found. Skipping...
# Processing Record 42 of Set 4 | ndjole
# Processing Record 43 of Set 4 | alice springs
# City not found. Skipping...
# Processing Record 44 of Set 4 | bubaque
# Processing Record 45 of Set 4 | kenai
# Processing Record 46 of Set 4 | dharmanagar
# Processing Record 47 of Set 4 | sao sebastiao
# City not found. Skipping...
# Processing Record 48 of Set 4 | dinar
# Processing Record 49 of Set 4 | saucillo
# Processing Record 50 of Set 4 | port hedland
# City not found. Skipping...
# Processing Record 1 of Set 5 | ruteng
# Processing Record 2 of Set 5 | nishihara
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | deer lake
# City not found. Skipping...
# Processing Record 5 of Set 5 | chapada dos guimaraes
# City not found. Skipping...
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | cockburn town
# City not found. Skipping...
# Processing Record 8 of Set 5 | hoima
# Processing Record 9 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 5 | itoman
# Processing Record 11 of Set 5 | puerto ayora
# City not found. Skipping...
# Processing Record 12 of Set 5 | santa isabel do rio negro
# City not found. Skipping...
# Processing Record 13 of Set 5 | mogadishu
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | krasnyy chikoy
# City not found. Skipping...
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | zhanakorgan
# Processing Record 18 of Set 5 | ramnagar
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | eugene
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | kemin
# Processing Record 23 of Set 5 | dhidhdhoo
# Processing Record 24 of Set 5 | nioro
# Processing Record 25 of Set 5 | aksarka
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | christchurch
# Processing Record 28 of Set 5 | novikovo
# Processing Record 29 of Set 5 | muhos
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | ponta delgada
# City not found. Skipping...
# Processing Record 32 of Set 5 | plouzane
# Processing Record 33 of Set 5 | srednekolymsk
# Processing Record 34 of Set 5 | llangefni
# Processing Record 35 of Set 5 | sabang
# Processing Record 36 of Set 5 | rostovka
# Processing Record 37 of Set 5 | bacungan
# Processing Record 38 of Set 5 | ashnak
# Processing Record 39 of Set 5 | coronado
# Processing Record 40 of Set 5 | namatanai
# Processing Record 41 of Set 5 | camargo
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | yepocapa
# Processing Record 46 of Set 5 | srivardhan
# Processing Record 47 of Set 5 | sayansk
# Processing Record 48 of Set 5 | pemangkat
# Processing Record 49 of Set 5 | san quintin
# City not found. Skipping...
# Processing Record 50 of Set 5 | sorland
# Processing Record 1 of Set 6 | zhanaozen
# Processing Record 2 of Set 6 | abeche
# Processing Record 3 of Set 6 | chutung
# City not found. Skipping...
# Processing Record 4 of Set 6 | miri
# Processing Record 5 of Set 6 | port keats
# City not found. Skipping...
# Processing Record 6 of Set 6 | krasnyy yar
# City not found. Skipping...
# Processing Record 7 of Set 6 | gustavo diaz ordaz
# City not found. Skipping...
# Processing Record 8 of Set 6 | kanker
# Processing Record 9 of Set 6 | oistins
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | yulara
# Processing Record 12 of Set 6 | yermish
# Processing Record 13 of Set 6 | bonavista
# Processing Record 14 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 6 | siderno
# Processing Record 16 of Set 6 | cabo san lucas
# City not found. Skipping...
# Processing Record 17 of Set 6 | roma
# Processing Record 18 of Set 6 | samoded
# Processing Record 19 of Set 6 | palasa
# Processing Record 20 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 6 | vaasa
# Processing Record 22 of Set 6 | san patricio
# City not found. Skipping...
# Processing Record 23 of Set 6 | eyl
# Processing Record 24 of Set 6 | khandyga
# Processing Record 25 of Set 6 | lewiston
# Processing Record 26 of Set 6 | mehamn
# Processing Record 27 of Set 6 | necochea
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | santa fe
# City not found. Skipping...
# Processing Record 30 of Set 6 | hanna
# Processing Record 31 of Set 6 | nantucket
# Processing Record 32 of Set 6 | deputatskiy
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | charters towers
# City not found. Skipping...
# Processing Record 35 of Set 6 | flin flon
# City not found. Skipping...
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | labuhan
# Processing Record 38 of Set 6 | burica
# City not found. Skipping...
# Processing Record 39 of Set 6 | kiunga
# Processing Record 40 of Set 6 | san policarpo
# City not found. Skipping...
# Processing Record 41 of Set 6 | punta alta
# City not found. Skipping...
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | carlyle
# Processing Record 44 of Set 6 | ushtobe
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | sao joao da barra
# City not found. Skipping...
# Processing Record 47 of Set 6 | chokurdakh
# Processing Record 48 of Set 6 | shu
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 50 of Set 6 | minot
# Processing Record 1 of Set 7 | pevek
# Processing Record 2 of Set 7 | vanimo
# Processing Record 3 of Set 7 | ketchenery
# City not found. Skipping...
# Processing Record 4 of Set 7 | abomsa
# Processing Record 5 of Set 7 | sabanagrande
# Processing Record 6 of Set 7 | timra
# Processing Record 7 of Set 7 | korla
# Processing Record 8 of Set 7 | colares
# Processing Record 9 of Set 7 | qena
# Processing Record 10 of Set 7 | gat
# Processing Record 11 of Set 7 | meilu
# City not found. Skipping...
# Processing Record 12 of Set 7 | shillong
# Processing Record 13 of Set 7 | egvekinot
# Processing Record 14 of Set 7 | tiarei
# Processing Record 15 of Set 7 | jalu
# Processing Record 16 of Set 7 | ilulissat
# Processing Record 17 of Set 7 | brownsville
# Processing Record 18 of Set 7 | falmouth
# Processing Record 19 of Set 7 | ternate
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | ledyard
# Processing Record 22 of Set 7 | kapit
# Processing Record 23 of Set 7 | dangriga
# Processing Record 24 of Set 7 | kokopo
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | ambilobe
# Processing Record 27 of Set 7 | sokoni
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | pushkinskiye gory
# City not found. Skipping...
# Processing Record 30 of Set 7 | pangkalanbuun
# Processing Record 31 of Set 7 | quatre cocos
# City not found. Skipping...
# Processing Record 32 of Set 7 | mahibadhoo
# Processing Record 33 of Set 7 | nhulunbuy
# Processing Record 34 of Set 7 | zakamensk
# Processing Record 35 of Set 7 | bourges
# Processing Record 36 of Set 7 | vila
# Processing Record 37 of Set 7 | kushima
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | panama city
# City not found. Skipping...
# Processing Record 40 of Set 7 | tilichiki
# Processing Record 41 of Set 7 | sola
# Processing Record 42 of Set 7 | minnetonka
# Processing Record 43 of Set 7 | silivri
# Processing Record 44 of Set 7 | lerwick
# Processing Record 45 of Set 7 | la ronge
# City not found. Skipping...
# Processing Record 46 of Set 7 | shubarkuduk
# Processing Record 47 of Set 7 | jardim
# Processing Record 48 of Set 7 | defiance
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 1 of Set 8 | jizan
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | chum phae
# City not found. Skipping...
# Processing Record 4 of Set 8 | sistranda
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | chara
# Processing Record 7 of Set 8 | port elizabeth
# City not found. Skipping...
# Processing Record 8 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | aykhal
# Processing Record 11 of Set 8 | narrabri
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | port-cartier
# Processing Record 14 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 8 | stepnogorsk
# Processing Record 16 of Set 8 | ayan
# Processing Record 17 of Set 8 | havelock
# Processing Record 18 of Set 8 | yar-sale
# Processing Record 19 of Set 8 | catamarca
# Processing Record 20 of Set 8 | phalodi
# Processing Record 21 of Set 8 | verkhnyaya inta
# City not found. Skipping...
# Processing Record 22 of Set 8 | gigmoto
# Processing Record 23 of Set 8 | esperance
# Processing Record 24 of Set 8 | pasighat
# Processing Record 25 of Set 8 | polewali
# Processing Record 26 of Set 8 | hervey bay
# City not found. Skipping...
# Processing Record 27 of Set 8 | ikongo
# Processing Record 28 of Set 8 | madang
# Processing Record 29 of Set 8 | vao
# Processing Record 30 of Set 8 | praia
# Processing Record 31 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 8 | madera
# Processing Record 33 of Set 8 | pekan
# Processing Record 34 of Set 8 | porto walter
# City not found. Skipping...
# Processing Record 35 of Set 8 | pascagoula
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | prince rupert
# City not found. Skipping...
# Processing Record 38 of Set 8 | sao felix do xingu
# City not found. Skipping...
# Processing Record 39 of Set 8 | chirawa
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | bima
# Processing Record 42 of Set 8 | hualmay
# Processing Record 43 of Set 8 | mokolo
# Processing Record 44 of Set 8 | mikkeli
# Processing Record 45 of Set 8 | salinopolis
# Processing Record 46 of Set 8 | viseu
# Processing Record 47 of Set 8 | tamazulapam
# City not found. Skipping...
# Processing Record 48 of Set 8 | dingle
# Processing Record 49 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 8 | yaan
# Processing Record 1 of Set 9 | moses lake
# City not found. Skipping...
# Processing Record 2 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 9 | kailua
# Processing Record 4 of Set 9 | oum hadjer
# City not found. Skipping...
# Processing Record 5 of Set 9 | marzuq
# Processing Record 6 of Set 9 | oranjemund
# Processing Record 7 of Set 9 | hastings
# Processing Record 8 of Set 9 | usinsk
# Processing Record 9 of Set 9 | puerto escondido
# City not found. Skipping...
# Processing Record 10 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 9 | astoria
# Processing Record 12 of Set 9 | orange
# Processing Record 13 of Set 9 | nouakchott
# Processing Record 14 of Set 9 | pangnirtung
# Processing Record 15 of Set 9 | gamba
# Processing Record 16 of Set 9 | fonte boa
# City not found. Skipping...
# Processing Record 17 of Set 9 | baft
# Processing Record 18 of Set 9 | shetpe
# Processing Record 19 of Set 9 | chulym
# Processing Record 20 of Set 9 | pallasovka
# Processing Record 21 of Set 9 | ostrovnoy
# Processing Record 22 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 9 | solnechnyy
# Processing Record 24 of Set 9 | ixtapa
# Processing Record 25 of Set 9 | lengshuijiang
# Processing Record 26 of Set 9 | capao da canoa
# City not found. Skipping...
# Processing Record 27 of Set 9 | alibag
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | uitenhage
# Processing Record 30 of Set 9 | gejiu
# Processing Record 31 of Set 9 | dunedin
# Processing Record 32 of Set 9 | perigueux
# Processing Record 33 of Set 9 | queimadas
# Processing Record 34 of Set 9 | cheney
# Processing Record 35 of Set 9 | nanortalik
# Processing Record 36 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 9 | camabatela
# Processing Record 38 of Set 9 | port lincoln
# City not found. Skipping...
# Processing Record 39 of Set 9 | port blair
# City not found. Skipping...
# Processing Record 40 of Set 9 | kyrylivka
# Processing Record 41 of Set 9 | chimbote
# Processing Record 42 of Set 9 | luanda
# Processing Record 43 of Set 9 | staunton
# Processing Record 44 of Set 9 | bure
# Processing Record 45 of Set 9 | grootfontein
# Processing Record 46 of Set 9 | san juan
# City not found. Skipping...
# Processing Record 47 of Set 9 | fairbanks
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | krasnoarmeysk
# Processing Record 50 of Set 9 | ninghai
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | ayagoz
# Processing Record 3 of Set 10 | vaitape
# Processing Record 4 of Set 10 | opuwo
# Processing Record 5 of Set 10 | zheleznodorozhnyy
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | jinchang
# Processing Record 8 of Set 10 | forbes
# Processing Record 9 of Set 10 | abha
# Processing Record 10 of Set 10 | ariquemes
# Processing Record 11 of Set 10 | lydenburg
# Processing Record 12 of Set 10 | al
# City not found. Skipping...
# Processing Record 13 of Set 10 | redding
# Processing Record 14 of Set 10 | rabaul
# Processing Record 15 of Set 10 | acapulco
# Processing Record 16 of Set 10 | heias
# City not found. Skipping...
# Processing Record 17 of Set 10 | dombarovskiy
# Processing Record 18 of Set 10 | lesosibirsk
# Processing Record 19 of Set 10 | waddan
# Processing Record 20 of Set 10 | mwingi
# Processing Record 21 of Set 10 | palmer
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | warwick
# Processing Record 25 of Set 10 | wad rawah
# City not found. Skipping...
# Processing Record 26 of Set 10 | oskemen
# Processing Record 27 of Set 10 | ornskoldsvik
# Processing Record 28 of Set 10 | sinjar
# Processing Record 29 of Set 10 | auki
# Processing Record 30 of Set 10 | channel-port aux basques
# City not found. Skipping...
# Processing Record 31 of Set 10 | alice
# Processing Record 32 of Set 10 | half moon bay
# City not found. Skipping...
# Processing Record 33 of Set 10 | awbari
# Processing Record 34 of Set 10 | bandar
# Processing Record 35 of Set 10 | kirs
# Processing Record 36 of Set 10 | lavrentiya
# Processing Record 37 of Set 10 | mega
# Processing Record 38 of Set 10 | wawa
# Processing Record 39 of Set 10 | halifax
# Processing Record 40 of Set 10 | palu
# Processing Record 41 of Set 10 | ouargaye
# Processing Record 42 of Set 10 | san carlos
# City not found. Skipping...
# Processing Record 43 of Set 10 | tigil
# Processing Record 44 of Set 10 | lujiang
# Processing Record 45 of Set 10 | chongwe
# Processing Record 46 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 10 | port macquarie
# City not found. Skipping...
# Processing Record 48 of Set 10 | touba
# Processing Record 49 of Set 10 | kurchum
# Processing Record 50 of Set 10 | mabaruma
# Processing Record 1 of Set 11 | thaton
# Processing Record 2 of Set 11 | djibo
# Processing Record 3 of Set 11 | antofagasta
# Processing Record 4 of Set 11 | live oak
# City not found. Skipping...
# Processing Record 5 of Set 11 | sabla
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | severo-yeniseyskiy
# Processing Record 8 of Set 11 | jaisalmer
# Processing Record 9 of Set 11 | moose factory
# City not found. Skipping...
# Processing Record 10 of Set 11 | yumen
# Processing Record 11 of Set 11 | grand baie
# City not found. Skipping...
# Processing Record 12 of Set 11 | melendugno
# Processing Record 13 of Set 11 | alta floresta
# City not found. Skipping...
# Processing Record 14 of Set 11 | tyukhtet
# Processing Record 15 of Set 11 | sorong
# Processing Record 16 of Set 11 | selfoss
# Processing Record 17 of Set 11 | porto santo
# City not found. Skipping...
# Processing Record 18 of Set 11 | qujing
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | palmas bellas
# City not found. Skipping...
# Processing Record 21 of Set 11 | cap malheureux
# City not found. Skipping...
# Processing Record 22 of Set 11 | nemuro
# Processing Record 23 of Set 11 | marsa matruh
# City not found. Skipping...
# Processing Record 24 of Set 11 | nizhniy kuranakh
# City not found. Skipping...
# Processing Record 25 of Set 11 | stettler
# Processing Record 26 of Set 11 | broken hill
# City not found. Skipping...
# Processing Record 27 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 11 | dimbokro
# Processing Record 29 of Set 11 | freeport
# Processing Record 30 of Set 11 | pirapora
# Processing Record 31 of Set 11 | linxia
# Processing Record 32 of Set 11 | ribeirao branco
# City not found. Skipping...
# Processing Record 33 of Set 11 | tokonou
# Processing Record 34 of Set 11 | bang saphan
# City not found. Skipping...
# Processing Record 35 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 11 | acari
# Processing Record 37 of Set 11 | barra patuca
# City not found. Skipping...
# Processing Record 38 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 11 | sao domingos
# City not found. Skipping...
# Processing Record 40 of Set 11 | sovetskiy
# Processing Record 41 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 11 | el cairo
# City not found. Skipping...
# Processing Record 43 of Set 11 | porto murtinho
# City not found. Skipping...
# Processing Record 44 of Set 11 | hay river
# City not found. Skipping...
# Processing Record 45 of Set 11 | pitimbu
# Processing Record 46 of Set 11 | viesca
# Processing Record 47 of Set 11 | paracuru
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | dukat
# Processing Record 50 of Set 11 | mkushi
# Processing Record 1 of Set 12 | sai buri
# City not found. Skipping...
# Processing Record 2 of Set 12 | mitsamiouli
# Processing Record 3 of Set 12 | peniche
# Processing Record 4 of Set 12 | belaya gora
# City not found. Skipping...
# Processing Record 5 of Set 12 | ambulu
# Processing Record 6 of Set 12 | xuchang
# Processing Record 7 of Set 12 | leninskoye
# Processing Record 8 of Set 12 | tabuk
# Processing Record 9 of Set 12 | dakar
# Processing Record 10 of Set 12 | anloga
# Processing Record 11 of Set 12 | mao
# Processing Record 12 of Set 12 | omsukchan
# Processing Record 13 of Set 12 | ancud
# Processing Record 14 of Set 12 | americus
# Processing Record 15 of Set 12 | shouguang
# Processing Record 16 of Set 12 | te anau
# City not found. Skipping...
# Processing Record 17 of Set 12 | staryy biser
# City not found. Skipping...
# Processing Record 18 of Set 12 | novyye gorki
# City not found. Skipping...
# Processing Record 19 of Set 12 | pocone
# Processing Record 20 of Set 12 | henties bay
# City not found. Skipping...
# Processing Record 21 of Set 12 | loandjili
# Processing Record 22 of Set 12 | verkhniy naur
# City not found. Skipping...
# Processing Record 23 of Set 12 | baykit
# Processing Record 24 of Set 12 | zig
# Processing Record 25 of Set 12 | meiganga
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | ayr
# Processing Record 28 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 12 | knysna
# Processing Record 30 of Set 12 | teguise
# Processing Record 31 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 32 of Set 12 | kinanah
# City not found. Skipping...
# Processing Record 33 of Set 12 | austintown
# Processing Record 34 of Set 12 | bitung
# Processing Record 35 of Set 12 | lastoursville
# Processing Record 36 of Set 12 | lhokseumawe
# Processing Record 37 of Set 12 | asosa
# Processing Record 38 of Set 12 | salo
# Processing Record 39 of Set 12 | gelibolu
# Processing Record 40 of Set 12 | mayo
# Processing Record 41 of Set 12 | tres picos
# City not found. Skipping...
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | nokaneng
# Processing Record 44 of Set 12 | tillabery
# City not found. Skipping...
# Processing Record 45 of Set 12 | biak
# Processing Record 46 of Set 12 | yerbogachen
# Processing Record 47 of Set 12 | victor harbor
# City not found. Skipping...
# Processing Record 48 of Set 12 | albion
# Processing Record 49 of Set 12 | ismailia
# Processing Record 50 of Set 12 | pandan
# Processing Record 1 of Set 13 | rabat
# Processing Record 2 of Set 13 | kumo
# Processing Record 3 of Set 13 | vuktyl
# Processing Record 4 of Set 13 | paamiut
# Processing Record 5 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 6 of Set 13 | mount gambier
# City not found. Skipping...
# Processing Record 7 of Set 13 | san francisco
# City not found. Skipping...
# Processing Record 8 of Set 13 | qasigiannguit
# Processing Record 9 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 13 | coihaique
# Processing Record 11 of Set 13 | nara
# Processing Record 12 of Set 13 | taunggyi
# Processing Record 13 of Set 13 | mackay
# Processing Record 14 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 13 | craig
# Processing Record 16 of Set 13 | pertuis
# Processing Record 17 of Set 13 | herat
# Processing Record 18 of Set 13 | turukhansk
# Processing Record 19 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 13 | vermilion
# Processing Record 21 of Set 13 | salalah
# Processing Record 22 of Set 13 | rincon
# Processing Record 23 of Set 13 | huangchuan
# Processing Record 24 of Set 13 | biograd na moru
# City not found. Skipping...
# Processing Record 25 of Set 13 | tupancireta
# Processing Record 26 of Set 13 | nador
# Processing Record 27 of Set 13 | svetlyy
# Processing Record 28 of Set 13 | morgan city
# City not found. Skipping...
# Processing Record 29 of Set 13 | padang
# Processing Record 30 of Set 13 | lagoa
# Processing Record 31 of Set 13 | lincoln
# Processing Record 32 of Set 13 | lawrenceburg
# Processing Record 33 of Set 13 | yhu
# Processing Record 34 of Set 13 | tongliao
# Processing Record 35 of Set 13 | north bend
# City not found. Skipping...
# Processing Record 36 of Set 13 | tatawin
# Processing Record 37 of Set 13 | burnie
# Processing Record 38 of Set 13 | nizhniy odes
# City not found. Skipping...
# Processing Record 39 of Set 13 | whitehorse
# Processing Record 40 of Set 13 | khed brahma
# City not found. Skipping...
# Processing Record 41 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | rawatsar
# Processing Record 43 of Set 13 | negombo
# Processing Record 44 of Set 13 | marystown
# Processing Record 45 of Set 13 | pitanga
# Processing Record 46 of Set 13 | sioux lookout
# City not found. Skipping...
# Processing Record 47 of Set 13 | mbanza-ngungu
# Processing Record 48 of Set 13 | karia
# Processing Record 49 of Set 13 | karratha
# Processing Record 50 of Set 13 | byron bay
# City not found. Skipping...
# Processing Record 1 of Set 14 | gomez plata
# City not found. Skipping...
# Processing Record 2 of Set 14 | natitingou
# Processing Record 3 of Set 14 | weihai
# Processing Record 4 of Set 14 | marsaxlokk
# Processing Record 5 of Set 14 | obama
# Processing Record 6 of Set 14 | rumford
# Processing Record 7 of Set 14 | termoli
# Processing Record 8 of Set 14 | kirakira
# Processing Record 9 of Set 14 | bezhetsk
# Processing Record 10 of Set 14 | calama
# Processing Record 11 of Set 14 | aksu
# Processing Record 12 of Set 14 | iwanuma
# Processing Record 13 of Set 14 | kidal
# Processing Record 14 of Set 14 | general teran
# City not found. Skipping...
# Processing Record 15 of Set 14 | huarmey
# Processing Record 16 of Set 14 | matagami
# Processing Record 17 of Set 14 | saint anthony
# City not found. Skipping...
# Processing Record 18 of Set 14 | luderitz
# Processing Record 19 of Set 14 | lata
# Processing Record 20 of Set 14 | ilebo
# Processing Record 21 of Set 14 | great yarmouth
# City not found. Skipping...
# Processing Record 22 of Set 14 | yenagoa
# Processing Record 23 of Set 14 | altayskoye
# Processing Record 24 of Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 25 of Set 14 | ravar
# Processing Record 26 of Set 14 | wamba
# Processing Record 27 of Set 14 | igrim
# Processing Record 28 of Set 14 | ayna
# Processing Record 29 of Set 14 | maple creek
# City not found. Skipping...
# Processing Record 30 of Set 14 | vestmannaeyjar
# Processing Record 31 of Set 14 | cocobeach
# Processing Record 32 of Set 14 | shingu
# Processing Record 33 of Set 14 | campo maior
# City not found. Skipping...
# Processing Record 34 of Set 14 | neiafu
# Processing Record 35 of Set 14 | luena
# Processing Record 36 of Set 14 | markova
# Processing Record 37 of Set 14 | boca do acre
# City not found. Skipping...
# Processing Record 38 of Set 14 | chor
# Processing Record 39 of Set 14 | lima
# Processing Record 40 of Set 14 | havre-saint-pierre
# Processing Record 41 of Set 14 | yebaishou
# Processing Record 42 of Set 14 | fuerte olimpo
# City not found. Skipping...
# Processing Record 43 of Set 14 | semey
# Processing Record 44 of Set 14 | santa clara
# City not found. Skipping...
# Processing Record 45 of Set 14 | mandalgovi
# Processing Record 46 of Set 14 | urumqi
# Processing Record 47 of Set 14 | savannah bight
# City not found. Skipping...
# Processing Record 48 of Set 14 | wagar
# Processing Record 49 of Set 14 | puerto del rosario
# City not found. Skipping...
# Processing Record 50 of Set 14 | haines junction
# City not found. Skipping...
# Processing Record 1 of Set 15 | troitsko-pechorsk
# Processing Record 2 of Set 15 | yuancheng
# Processing Record 3 of Set 15 | safaga
# Processing Record 4 of Set 15 | ibra
# Processing Record 5 of Set 15 | salsk
# Processing Record 6 of Set 15 | iqaluit
# Processing Record 7 of Set 15 | yangcun
# Processing Record 8 of Set 15 | angoche
# Processing Record 9 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 15 | shatki
# Processing Record 11 of Set 15 | frutal
# Processing Record 12 of Set 15 | isla vista
# City not found. Skipping...
# Processing Record 13 of Set 15 | dabat
# Processing Record 14 of Set 15 | romny
# Processing Record 15 of Set 15 | cairns
# Processing Record 16 of Set 15 | kieta
# Processing Record 17 of Set 15 | vengerovo
# Processing Record 18 of Set 15 | yarmouth
# Processing Record 19 of Set 15 | el sauzal
# City not found. Skipping...
# Processing Record 20 of Set 15 | marsh harbour
# City not found. Skipping...
# Processing Record 21 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 15 | igarka
# Processing Record 23 of Set 15 | boa vista
# City not found. Skipping...
# Processing Record 24 of Set 15 | chapais
# Processing Record 25 of Set 15 | marondera
# Processing Record 26 of Set 15 | quartucciu
# Processing Record 27 of Set 15 | pimenteiras
# Processing Record 28 of Set 15 | uray
# Processing Record 29 of Set 15 | porto velho
# City not found. Skipping...
# Processing Record 30 of Set 15 | bissau
# Processing Record 31 of Set 15 | pacific grove
# City not found. Skipping...
# Processing Record 32 of Set 15 | sibolga
# Processing Record 33 of Set 15 | iskateley
# Processing Record 34 of Set 15 | beloha
# Processing Record 35 of Set 15 | kimbe
# Processing Record 36 of Set 15 | venado tuerto
# City not found. Skipping...
# Processing Record 37 of Set 15 | luancheng
# Processing Record 38 of Set 15 | avera
# Processing Record 39 of Set 15 | sisimiut
# Processing Record 40 of Set 15 | ketchikan
# Processing Record 41 of Set 15 | san andres
# City not found. Skipping...
# Processing Record 42 of Set 15 | ritchie
# Processing Record 43 of Set 15 | patacamaya
# Processing Record 44 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 15 | umba
# Processing Record 46 of Set 15 | ahuimanu
# Processing Record 47 of Set 15 | estelle
# Processing Record 48 of Set 15 | minbu
# Processing Record 49 of Set 15 | villa maria
# City not found. Skipping...
# Processing Record 50 of Set 15 | miyako
# Processing Record 1 of Set 16 | bambanglipuro
# Processing Record 2 of Set 16 | axim
# Processing Record 3 of Set 16 | lovozero
# Processing Record 4 of Set 16 | arshan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 562

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City     Lat:       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Victoria  22.2855  114.1577     75.38        90          99       13.00
# 1       Esna  25.2934   32.5540     85.24        26           0       10.29
# 2     Hobart -42.8794  147.3294     55.26        74         100       12.66
# 3     Hasaki  35.7333  140.8333     55.22        92         100       18.21
# 4    Bambari   5.7680   20.6757     92.66        32         100        3.31
# 5       Atar  20.5169  -13.0499     83.01         8           0       13.02
# 6     Laguna  38.4210 -121.4238     51.01        84           0        0.00
# 7  Grindavik  63.8424  -22.4338     39.67        52           0       33.38
# 8     Albany  42.6001  -73.9662     36.73        80          18        3.27
# 9      Sembe   1.6481   14.5806     87.40        48          91        3.76
#
#   Country      Description
# 0      HK  overcast clouds
# 1      EG        clear sky
# 2      AU  overcast clouds
# 3      JP    moderate rain
# 4      CF  overcast clouds
# 5      MR        clear sky
# 6      US        clear sky
# 7      IS        clear sky
# 8      US       few clouds
# 9      CG  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat:', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Rename "Description" to "Current Description", rename "Lat:" to "Lat"
# to avoid gathering all the data again.
city_data_df = city_data_df.rename(columns={"Description":"Current Description","Lat:":"Lat"})

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reordered_columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_columns]

# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Victoria      HK  22.2855  114.1577     75.38        90          99
# 1       Esna      EG  25.2934   32.5540     85.24        26           0
# 2     Hobart      AU -42.8794  147.3294     55.26        74         100
# 3     Hasaki      JP  35.7333  140.8333     55.22        92         100
# 4    Bambari      CF   5.7680   20.6757     92.66        32         100
# 5       Atar      MR  20.5169  -13.0499     83.01         8           0
# 6     Laguna      US  38.4210 -121.4238     51.01        84           0
# 7  Grindavik      IS  63.8424  -22.4338     39.67        52           0
# 8     Albany      US  42.6001  -73.9662     36.73        80          18
# 9      Sembe      CG   1.6481   14.5806     87.40        48          91
#
#    Wind Speed Current Description
# 0       13.00     overcast clouds
# 1       10.29           clear sky
# 2       12.66     overcast clouds
# 3       18.21       moderate rain
# 4        3.31     overcast clouds
# 5       13.02           clear sky
# 6        0.00           clear sky
# 7       33.38           clear sky
# 8        3.27          few clouds
# 9        3.76     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
